# %% [markdown]
# <a href="https://colab.research.google.com/github/M-aljawaheri/Fool-me-once-defense/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone https://github.com/M-aljawaheri/Fool-me-once-defense.git
# Out:
# Cloning into 'Fool-me-once-defense'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# %cd Fool-me-once-defense/
# Out:
# /content/Fool-me-once-defense

# %%
# !ls
# Out:
# README.md

# %%
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Out:
# --2021-04-06 14:00:44--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/x-tar]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  9.09MB/s    in 51s
#
# 2021-04-06 14:01:35 (8.58 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]

# %%
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# !wget http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCdevkit_08-Jun-2007.tar
# Out:
# --2021-04-06 14:03:28--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/x-tar]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  9.19MB/s    in 49s
#
# 2021-04-06 14:04:17 (8.71 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]
#
# --2021-04-06 14:04:18--  http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCdevkit_08-Jun-2007.tar
# Resolving host.robots.ox.ac.uk (host.robots.ox.ac.uk)... 129.67.94.152
# Connecting to host.robots.ox.ac.uk (host.robots.ox.ac.uk)|129.67.94.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256000 (250K) [application/x-tar]
# Saving to: ‘VOCdevkit_08-Jun-2007.tar’
#
# ...

# %%
# !git config --global user.Username M-aljawaheri

# %%
# !git commit -m "VOC dataset added"
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006257.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006258.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006259.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006260.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006261.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006262.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006263.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006264.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006265.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006266.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006267.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006268.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006269.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006270.jpg
#  create mode 100644 VOCdevkit/VOC2007/JPEGImages/006271.jpg
# ...

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
